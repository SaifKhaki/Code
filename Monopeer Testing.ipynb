# %%
import socket
import psutil as p
import yaml
import os
import pynvml
import threading
import speedtest
import math
# ML Specific
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

def train_and_predict(df, df2):
    X = df[[i for i in list(df.columns)[:-1]]]
    y = df.Target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    models = {
        "knn": {"model":KNeighborsClassifier()}
    }

    for name, model in models.items():
        model['model'].fit(X_train, y_train)
        
    models_acc = []
    for name, model in models.items():
        models_acc.append(model["model"].score(X_test, y_test))
    print("sf::", models_acc)
    
    for name, model in models.items():
        prediction = model['model'].predict(df2)
        
    return prediction

# %%
df= pd.read_csv("Scoring.csv")

# %%
import os, psutil; 
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
for index, rows in df[list(df.columns)[:-1]].iterrows():
    print(train_and_predict(df, pd.DataFrame([rows.values.tolist()], columns=list(df.columns)[:-1])))
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 130.671875
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ['Scored']
# sf:: [1.0]
# ...

# %%
import os
# get the size of file
size = os.path.getsize('Scoring.csv') 
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2,"MB Ram usage by mono-peer for a dataset file of", size,"bytes")
# Out:
# 130.671875 MB Ram usage by mono-peer for a dataset file of 5248 bytes
