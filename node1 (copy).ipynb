# %% [markdown]
# # Importing all important libraries

# %%
import socket
import psutil as p
import yaml
import os
import pynvml
import threading
import speedtest
import math
# ML Specific
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # Initializing important variables

# %%
# Read YAML file
with open("config.yaml", 'r') as stream:
    config_loaded = yaml.safe_load(stream)
    
######################################## Connections ################################
# format: [(ip,port,connection)i] for i=onode_count
onodes_connections = []
# format: connection_object
snode_connection = None
server_connection = None
    
# Connecting to server's ip address
server_connection = socket.socket()
host = config_loaded["server"]["ip"]
port = config_loaded["server"]["port"]
o_nodes_count = config_loaded["kazaa"]["o_node_per"]

# %% [markdown]
# ### Formats:
#
# onodes_connections = [(ip,port,connection)i] for i=onode_count

# %% [markdown]
# snode_connection = connection_object

# %%
# Global Fields
status = ''
onodes = []
onodes_threads = [None]*o_nodes_count
snodes = []
self_kazaa_constant = 0
onodes_kazaa_constant = [0]*o_nodes_count
# this will be used to handle personal data
df = None

# %% [markdown]
# # Defining main functions required

# %%
# socket send consistent method 
# it sends the string, waits for the length of string client received, compares this length to the actual length. If both are equal
# it sends ack else, it resends the same txt again.
def socket_send(connection, txt):
    ack = False
    print(">>sending",txt+"...")
    while(not ack):
        connection.send(str.encode(txt))
        len_txt = int(connection.recv(1024).decode('utf-8'))
        if len_txt == len(txt):
            connection.send(str.encode("ack"))
            ack = True
        else:
            connection.send(str.encode("resending"))

# socket receive consistent method 
# it receives the string, then sends its size back to the server and then it waits for an acknowledgement, If ack is received it 
# breaks out of the loop
def socket_rcv(connection, size=1024):
    ack = False
    while(not ack):
        txt = connection.recv(size).decode('utf-8')
        connection.send(str.encode(str(len(txt))))
        ack = True if connection.recv(size).decode('utf-8') == "ack" else False
    print(">>received", txt+"...")
    return txt

def memory():
    mem = p.virtual_memory()
    return (mem.total, mem.available)

def cpu():
    return (100-p.cpu_percent(), p.cpu_count(logical=True))

def gpu_memory():
    try:
        pynvml.nvmlInit()
        # 1 here is the GPU id
        handle = pynvml.nvmlDeviceGetHandleByIndex(1)
        meminfo = pynvml.nvmlDeviceGetMemoryInfo(handle)
        return meminfo.free
    except:
        return 0

def download_speed():
    try:
        st = speedtest.Speedtest()
        return st.download()/8
    except:
        return 0
   
def receive_rows(connection):
    print("starting receiving rows")
    row_count_str = socket_rcv(connection)
    if row_count_str.startswith("rcv:"):
        row_count = int(row_count_str[len("rcv:"):])
        headers = socket_rcv(connection)[len("rcv:"):].split(":")
        print("row_count:", row_count, "headers:", headers)
        data = []
        for i in range(row_count):
            data_rcvd = socket_rcv(connection, 32768)
            while(data_rcvd.count(":") > 3):
                socket_send(connection, "resend")
                data_rcvd = socket_rcv(connection, 32768)
            data.append(data_rcvd.split(":"))
            socket_send(connection, "rcvd")
            print("Rcvd row:", data[-1][:-1])
    return pd.DataFrame(data, columns=headers)

def send_rows_onode(connection, df, division, index, headers):
    start = division[index - 1] if index > 0 else 0
    end = division[index]
    socket_send(connection, "rcv:"+str(end - start))
    socket_send(connection, "rcv:"+headers)
    for i, row in df[start:end].iterrows():
        socket_send(connection, str(row[0])+":"+str(row[1])+":"+str(row[2])+":"+str(row[3]))
        ack = socket_rcv(connection)
        while(ack != "rcvd"):
            socket_send(connection, str(row[0])+":"+str(row[1])+":"+str(row[2])+":"+str(row[3]))
            ack = socket_rcv(connection)
            
# here snode is sender and onode is receiver
def snode_onode_socket(connection, id):
    print("Waiting for kazaa_constant of",id,"ordinary node.")
    onodes_kazaa_constant[id] = float(socket_rcv(connection)[len("k_const:"):])
        
# here onode is sender and snode is receiver
def onode_snode_socket(connection):
    socket_send(connection, "k_const:"+str(self_kazaa_constant))
    df = receive_rows(connection)
    print("df received from supernode of my region has shape: ", df.shape)
    return df
 
def send_system_info():
    messages_to_send = 5
    socket_send(server_connection, "rcv:"+str(messages_to_send))
    # download speed in bytes
    socket_send(server_connection, "dsp:"+str(download_speed()))
    # available GPU ram in bytes
    socket_send(server_connection, "gpu:"+str(gpu_memory()))
    # available ram in bytes
    socket_send(server_connection, "ram:"+str(memory()[1]))
    # cpu free in percentage
    socket_send(server_connection, "cpu:"+str(cpu()[0]))
    # cpu cores in count
    socket_send(server_connection, "cor:"+str(cpu()[1]))
    
def train_and_predict(df, df2):
    X = df[[i for i in list(df.columns)[:-1]]]
    y = df.Target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    models = {
        "knn": {"model":KNeighborsClassifier()}
    }

    for name, model in models.items():
        model['model'].fit(X_train, y_train)
        
    models_acc = []
    for name, model in models.items():
        models_acc.append(model["model"].score(X_test, y_test))
    
    for name, model in models.items():
        prediction = model['model'].predict(df2)
        
    return prediction


def most_frequent(List):
    return max(set(List), key = List.count)

print("All defined perfectly")
# Out:
# All defined perfectly

# %% [markdown]
# # Starting our main socket

# %% [markdown]
# ### Sending system info

# %%
username = input("Input your username: ")
print('Waiting for connection response')
try:
    server_connection.connect((host, port))
    print("Connected")
except socket.error as e:
    print(str(e))
    
# first check response received i.e "Server is working"
res = socket_rcv(server_connection)
print(res)

# sending system info
send_system_info()
# Out:
# Input your username: ail
# Waiting for connection response
# Connected
# >>received Server is working:...
# Server is working:
# >>sending rcv:5...
# >>sending dsp:191531.06234391162...
# >>sending gpu:0...
# >>sending ram:11082366976...
# >>sending cpu:82.4...
# >>sending cor:4...

# %% [markdown]
# ### Receiving acknowledgement

# %%
# receive acknowledge
print("\n" + "/"*40 + " waiting for ack " + "/"*40)
res = socket_rcv(server_connection)
print(res)
# Out:
# //////////////////////////////////////// waiting for ack ////////////////////////////////////////
# >>received ack: received following system info:
# Download_speed = 191531.06234391162B
# Free_GPU_RAM = 0.0B
# Free_RAM = 11082366976.0B
# Free_CPU = 82.4
# CPU_Cores = 4...
# ack: received following system info:
# Download_speed = 191531.06234391162B
# Free_GPU_RAM = 0.0B
# Free_RAM = 11082366976.0B
# Free_CPU = 82.4
# CPU_Cores = 4

# %% [markdown]
# ### Receiving Status

# %%
# receive status in kazaa architecture
print("\n" + "/"*40 + " waiting for status " + "/"*40)
status = socket_rcv(server_connection)[len("status:"):]
# Out:
# //////////////////////////////////////// waiting for status ////////////////////////////////////////
# >>received status:o...

# %% [markdown]
# ### Receiving Kazaa Constant

# %%
print("\n" + "/"*40 + " waiting for kazaa constant " + "/"*40)
self_kazaa_constant = socket_rcv(server_connection)[len("k_const:"):]
# Out:
# //////////////////////////////////////// waiting for kazaa constant ////////////////////////////////////////
# >>received k_const:0.8285163917212575...

# %%
print("You are appointed as " + ("Super node" if status=="s" else "Ordinary node") + " with kazaa constant as", self_kazaa_constant)
# Out:
# You are appointed as Ordinary node with kazaa constant as 0.8285163917212575

# %% [markdown]
# # Super Node

# %% [markdown]
# ### Create a socket for ordinary nodes and send to server

# %%
if status == "s":
    onodesSocket = socket.socket()
    host = socket.gethostname()
    oport = port + 1
    while(True):
        try:
            onodesSocket.bind((host, oport))
            print("\n" + "/"*40 + " Supernode Socket " + "/"*40)
            print("Socket for listening to", o_nodes_count,"ordinary nodes is listening at "+host+":"+str(onodesSocket.getsockname()[1])+"\n")
            break
        except:
            oport += 1
    
    socket_send(server_connection, str(host+":"+str(onodesSocket.getsockname()[1])))
    # server_connection.send(str.encode(str(host+":"+str(onodesSocket.getsockname()[1]))))
    onodesSocket.listen(o_nodes_count)

# %% [markdown]
# ### Accept responses from ordinary nodes and as a result get their kazaa constant

# %%
if status == "s":
    # open your onode socket for onodes to get connect
    id = 0
    print("\n" + "/"*40 + " waiting for kazaa constant from each ordinary node " + "/"*20)
    print("Supernode is accepting responses from ordinary nodes...")
    while(id != o_nodes_count):
        Client, address = onodesSocket.accept()
        onodes_connections.append((address[0], address[1], Client))
        onodes_threads[id] = threading.Thread(target = snode_onode_socket, args=(Client, id))
        onodes_threads[id].start()
        # print('Thread Number: ' + str(id) + " - " + 'Connected to ordinary node: ' + address[0] + ':' + str(address[1]))
        id += 1

    # joining all the threads
    for i in onodes_threads:
        i.join()

# %% [markdown]
# ### Accept data for your region from server

# %%
if status == "s":
    #ensemble_distribution()
    # receive data from server
    print("\n" + "/"*40 + " waiting for region data " + "/"*40)
    df = receive_rows(server_connection)
    print("data rcvd from server for",df.shape[0],"rows with headers:",df.columns)

# %% [markdown]
# ### Get division of data for all nodes in region

# %%
if status == "s":
    division = []
    for i in onodes_kazaa_constant:
        division.append(math.ceil((df.shape[0]*i)/(sum(onodes_kazaa_constant)+float(self_kazaa_constant))))
    division.append(int(df.shape[0]*float(self_kazaa_constant)/sum(onodes_kazaa_constant)))
    division

# %% [markdown]
# ### Get headers for the data frame

# %%
if status == "s":
    headers = ":".join(list(df.columns))
    headers

# %% [markdown]
# ### Send respective data to each ordinary data

# %%
if status == "s":
    # firstly we'll shuffle the data 
    df = df.sample(frac=1).reset_index(drop=True)
    # data for regional ordinary nodes
    index = 0
    print("\n" + "/"*40 + " waiting to send data to ordinary nodes " + "/"*40)
    print("Sending data...")
    for onode_connection in onodes_connections:
        send_rows_onode(onode_connection[2], df, division, index, headers)
        print("Sent all data to", onode_connection[0], "at port", onode_connection[1])
        index += 1

# %% [markdown]
# ### Take out your own part of the data

# %%
if status == "s":
    df = df[division[-2]:division[-1]]
print("data i kept is:")
df
# Out:
# data i kept is:

# %% [markdown]
# ### Get x_test from server and Predict your own results firstly

# %%
if status == "s":
    print("\n" + "/"*40 + " waiting to receive predictions from region " + "/"*40)
    x_test = socket_rcv(server_connection)[len("rcv_test:"):]
    predictions = []
    print("Sending x_test...")
    for onode_connection in onodes_connections:
        socket_send(onode_connection[2], "rcv_test:"+x_test)
        predictions.append(socket_rcv(onode_connection[2]))
    print(">>>>>>>>>>>", my_prediction)
    predictions.append(train_and_predict(df, pd.DataFrame([x_test.split(":")], columns=[list(df.columns)[:-1]]))[0])
    predictions.reverse()
    print(most_frequent(predictions),"is the most frequent prediction from my region.")
    socket_send(server_connection, most_frequent(predictions))

# %%
if status == "s":
    for i in range(248):
        print("\n" + "/"*40 + " waiting to receive predictions from region " + "/"*40)
        x_test = socket_rcv(server_connection)[len("rcv_test:"):]
        predictions = []
        print("Sending x_test...")
        for onode_connection in onodes_connections:
            socket_send(onode_connection[2], "rcv_test:"+x_test)
            predictions.append(socket_rcv(onode_connection[2]))
        my_prediction = train_and_predict(df, pd.DataFrame([x_test.split(":")], columns=[list(df.columns)[:-1]]))[0]
        print(">>>>>>>>>>>", my_prediction)
        predictions.append(my_prediction)
        predictions.reverse()
        print(most_frequent(predictions),"is the most frequent prediction from my region.")
        socket_send(server_connection, most_frequent(predictions))

# %% [markdown]
# # Ordinary Node

# %% [markdown]
# ### Receiving IP:Port for super node of your current region

# %%
if status == "o":
    print("\n" + "/"*40 + " Ordinary Node Socket " + "/"*40)
    ip_port = socket_rcv(server_connection).split(":")
    snodes.append((ip_port[0], int(ip_port[1])))

    for ip,port in snodes:
        print("Snode of my region is present at "+ip+":"+str(port))
# Out:
# //////////////////////////////////////// Ordinary Node Socket ////////////////////////////////////////
# >>received ubuntu:4355...
# Snode of my region is present at ubuntu:4355

# %% [markdown]
# ### After sending a connection request to the super node, ordinary nodes sends its kazaa_constant and start receiving its share in the dataset

# %%
if status == "o":
# starting connections with onodes:
    print("\n" + "/"*40 + " waiting to receive data from super node " + "/"*40)
    i = 0
    for ip,port in snodes:
        try:
            snode_connection = socket.socket()
            snode_connection.connect((ip, port))
            print("Connected to the supernode.\n")
            df = onode_snode_socket(snode_connection)
        except socket.error as e:
            print(str(e))
        i += 1
# Out:
# //////////////////////////////////////// waiting to receive data from super node ////////////////////////////////////////
# Connected to the supernode.
#
# >>sending k_const:0.8285163917212575...
# starting receiving rows
# >>received rcv:124...
# >>received rcv:Acceleration:Speed(m/s):Angle:Target...
# row_count: 124 headers: ['Acceleration', 'Speed(m/s)', 'Angle', 'Target']
# >>received 43.1:26.5:14.6:Not-scored...
# >>sending rcvd...
# Rcvd row: ['43.1', '26.5', '14.6']
# >>received 63.0:17.0:11.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['63.0', '17.0', '11.0']
# >>received 251.0:23.0:12.6:Scored...
# >>sending rcvd...
# Rcvd row: ['251.0', '23.0', '12.6']
# >>received 306.0:20.82:59.0:Scored...
# >>sending rcvd...
# Rcvd row: ['306.0', '20.82', '59.0']
# >>received 133.0:30.0:66.0:Scored...
# >>sending rcvd...
# Rcvd row: ['133.0', '30.0', '66.0']
# >>received 40.1:23.5:11.6:Not-scored...
# >>sending rcvd...
# Rcvd row: ['40.1', '23.5', '11.6']
# >>received 123.0:29.0:31.0:Scored...
# >>sending rcvd...
# Rcvd row: ['123.0', '29.0', '31.0']
# >>received 75.0:26.0:12.5:Not-scored...
# >>sending rcvd...
# Rcvd row: ['75.0', '26.0', '12.5']
# >>received 196.0:19.0:18.0:Scored...
# >>sending rcvd...
# Rcvd row: ['196.0', '19.0', '18.0']
# >>received 69.0:23.0:17.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['69.0', '23.0', '17.0']
# >>received 165.0:32.0:21.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['165.0', '32.0', '21.0']
# >>received 295.0:20.35:59.0:Scored...
# >>sending rcvd...
# Rcvd row: ['295.0', '20.35', '59.0']
# >>received 124.0:23.6:47.8:Scored...
# >>sending rcvd...
# Rcvd row: ['124.0', '23.6', '47.8']
# >>received 194.0:36.0:40.0:Scored...
# >>sending rcvd...
# Rcvd row: ['194.0', '36.0', '40.0']
# >>received 87.0:16.0:17.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['87.0', '16.0', '17.0']
# >>received 91.0:20.0:21.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['91.0', '20.0', '21.0']
# >>received 252.0:24.0:13.6:Scored...
# >>sending rcvd...
# Rcvd row: ['252.0', '24.0', '13.6']
# >>received 124.0:35.6:21.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['124.0', '35.6', '21.2']
# >>received 88.5:41.0:16.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['88.5', '41.0', '16.8']
# >>received 70.0:24.0:18.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['70.0', '24.0', '18.0']
# >>received 202.0:40.0:69.0:Scored...
# >>sending rcvd...
# Rcvd row: ['202.0', '40.0', '69.0']
# >>received 311.0:25.82:64.0:Scored...
# >>sending rcvd...
# Rcvd row: ['311.0', '25.82', '64.0']
# >>received 120.0:19.6:43.8:Scored...
# >>sending rcvd...
# Rcvd row: ['120.0', '19.6', '43.8']
# >>received 121.0:32.6:18.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['121.0', '32.6', '18.2']
# >>received 125.0:25.0:49.0:Scored...
# >>sending rcvd...
# Rcvd row: ['125.0', '25.0', '49.0']
# >>received 184.0:53.6:14.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['184.0', '53.6', '14.8']
# >>received 126.0:25.6:49.8:Scored...
# >>sending rcvd...
# Rcvd row: ['126.0', '25.6', '49.8']
# >>received 156.0:34.0:42.0:Scored...
# >>sending rcvd...
# Rcvd row: ['156.0', '34.0', '42.0']
# >>received 191.0:33.0:37.0:Scored...
# >>sending rcvd...
# Rcvd row: ['191.0', '33.0', '37.0']
# >>received 18.0:6.52:11.3:Not-scored...
# >>sending rcvd...
# Rcvd row: ['18.0', '6.52', '11.3']
# >>received 205.0:26.0:43.3:Scored...
# >>sending rcvd...
# Rcvd row: ['205.0', '26.0', '43.3']
# >>received 195.0:33.0:62.0:Scored...
# >>sending rcvd...
# Rcvd row: ['195.0', '33.0', '62.0']
# >>received 92.5:45.0:20.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['92.5', '45.0', '20.8']
# >>received 204.0:25.0:42.3:Scored...
# >>sending rcvd...
# Rcvd row: ['204.0', '25.0', '42.3']
# >>received 21.0:9.52:14.3:Not-scored...
# >>sending rcvd...
# Rcvd row: ['21.0', '9.52', '14.3']
# >>received 127.0:27.0:51.0:Scored...
# >>sending rcvd...
# Rcvd row: ['127.0', '27.0', '51.0']
# >>received 198.0:21.0:20.0:Scored...
# >>sending rcvd...
# Rcvd row: ['198.0', '21.0', '20.0']
# >>received 186.0:28.0:32.0:Scored...
# >>sending rcvd...
# Rcvd row: ['186.0', '28.0', '32.0']
# >>received 139.0:36.0:72.0:Scored...
# >>sending rcvd...
# Rcvd row: ['139.0', '36.0', '72.0']
# >>received 412.0:36.0:14.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['412.0', '36.0', '14.0']
# >>received 121.0:27.0:29.0:Scored...
# >>sending rcvd...
# Rcvd row: ['121.0', '27.0', '29.0']
# >>received 259.0:31.0:20.6:Scored...
# >>sending rcvd...
# Rcvd row: ['259.0', '31.0', '20.6']
# >>received 82.0:33.0:19.5:Not-scored...
# >>sending rcvd...
# Rcvd row: ['82.0', '33.0', '19.5']
# >>received 407.0:31.0:9.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['407.0', '31.0', '9.0']
# >>received 202.0:25.0:24.0:Scored...
# >>sending rcvd...
# Rcvd row: ['202.0', '25.0', '24.0']
# >>received 164.0:31.0:20.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['164.0', '31.0', '20.0']
# >>received 214.0:22.26:63.0:Scored...
# >>sending rcvd...
# Rcvd row: ['214.0', '22.26', '63.0']
# >>received 199.0:22.0:21.0:Scored...
# >>sending rcvd...
# Rcvd row: ['199.0', '22.0', '21.0']
# >>received 91.5:44.0:19.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['91.5', '44.0', '19.8']
# >>received 85.5:38.0:13.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['85.5', '38.0', '13.8']
# >>received 201.0:39.0:68.0:Scored...
# >>sending rcvd...
# Rcvd row: ['201.0', '39.0', '68.0']
# >>received 83.5:36.0:11.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['83.5', '36.0', '11.8']
# >>received 25.0:13.52:18.3:Not-scored...
# >>sending rcvd...
# Rcvd row: ['25.0', '13.52', '18.3']
# >>received 117.0:23.0:25.0:Scored...
# >>sending rcvd...
# Rcvd row: ['117.0', '23.0', '25.0']
# >>received 87.5:40.0:15.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['87.5', '40.0', '15.8']
# >>received 38.1:21.5:9.6:Not-scored...
# >>sending rcvd...
# Rcvd row: ['38.1', '21.5', '9.6']
# >>received 296.0:21.35:60.0:Scored...
# >>sending rcvd...
# Rcvd row: ['296.0', '21.35', '60.0']
# >>received 208.0:29.0:46.3:Scored...
# >>sending rcvd...
# Rcvd row: ['208.0', '29.0', '46.3']
# >>received 213.0:21.26:62.0:Scored...
# >>sending rcvd...
# Rcvd row: ['213.0', '21.26', '62.0']
# >>received 96.0:25.0:26.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['96.0', '25.0', '26.0']
# >>received 77.0:28.0:14.5:Not-scored...
# >>sending rcvd...
# Rcvd row: ['77.0', '28.0', '14.5']
# >>received 203.0:26.0:25.0:Scored...
# >>sending rcvd...
# Rcvd row: ['203.0', '26.0', '25.0']
# >>received 183.0:52.6:13.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['183.0', '52.6', '13.8']
# >>received 117.0:28.6:14.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['117.0', '28.6', '14.2']
# >>received 125.0:24.6:48.8:Scored...
# >>sending rcvd...
# Rcvd row: ['125.0', '24.6', '48.8']
# >>received 122.0:21.6:45.8:Scored...
# >>sending rcvd...
# Rcvd row: ['122.0', '21.6', '45.8']
# >>received 163.0:30.0:19.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['163.0', '30.0', '19.0']
# >>received 211.0:19.26:60.0:Scored...
# >>sending rcvd...
# Rcvd row: ['211.0', '19.26', '60.0']
# >>received 118.0:24.0:26.0:Scored...
# >>sending rcvd...
# Rcvd row: ['118.0', '24.0', '26.0']
# >>received 162.0:43.0:51.0:Scored...
# >>sending rcvd...
# Rcvd row: ['162.0', '43.0', '51.0']
# >>received 201.0:39.0:68.0:Scored...
# >>sending rcvd...
# Rcvd row: ['201.0', '39.0', '68.0']
# >>received 219.0:27.26:68.0:Scored...
# >>sending rcvd...
# Rcvd row: ['219.0', '27.26', '68.0']
# >>received 61.0:15.0:9.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['61.0', '15.0', '9.0']
# >>received 134.0:31.0:67.0:Scored...
# >>sending rcvd...
# Rcvd row: ['134.0', '31.0', '67.0']
# >>received 189.0:31.0:35.0:Scored...
# >>sending rcvd...
# Rcvd row: ['189.0', '31.0', '35.0']
# >>received 207.0:28.0:45.3:Scored...
# >>sending rcvd...
# Rcvd row: ['207.0', '28.0', '45.3']
# >>received 206.0:27.0:44.3:Scored...
# >>sending rcvd...
# Rcvd row: ['206.0', '27.0', '44.3']
# >>received 120.0:31.6:17.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['120.0', '31.6', '17.2']
# >>received 121.0:20.6:44.8:Scored...
# >>sending rcvd...
# Rcvd row: ['121.0', '20.6', '44.8']
# >>received 254.0:26.0:15.6:Scored...
# >>sending rcvd...
# Rcvd row: ['254.0', '26.0', '15.6']
# >>received 253.0:25.0:14.6:Scored...
# >>sending rcvd...
# Rcvd row: ['253.0', '25.0', '14.6']
# >>received 258.0:30.0:19.6:Scored...
# >>sending rcvd...
# Rcvd row: ['258.0', '30.0', '19.6']
# >>received 122.0:22.0:46.0:Scored...
# >>sending rcvd...
# Rcvd row: ['122.0', '22.0', '46.0']
# >>received 163.0:41.0:49.0:Scored...
# >>sending rcvd...
# Rcvd row: ['163.0', '41.0', '49.0']
# >>received 195.0:33.0:62.0:Scored...
# >>sending rcvd...
# Rcvd row: ['195.0', '33.0', '62.0']
# >>received 126.0:26.0:50.0:Scored...
# >>sending rcvd...
# Rcvd row: ['126.0', '26.0', '50.0']
# >>received 218.0:26.26:67.0:Scored...
# >>sending rcvd...
# Rcvd row: ['218.0', '26.26', '67.0']
# >>received 66.0:20.0:14.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['66.0', '20.0', '14.0']
# >>received 89.0:18.0:19.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['89.0', '18.0', '19.0']
# >>received 192.0:34.0:38.0:Scored...
# >>sending rcvd...
# Rcvd row: ['192.0', '34.0', '38.0']
# >>received 19.0:7.52:12.3:Not-scored...
# >>sending rcvd...
# Rcvd row: ['19.0', '7.52', '12.3']
# >>received 164.0:45.0:53.0:Scored...
# >>sending rcvd...
# Rcvd row: ['164.0', '45.0', '53.0']
# >>received 158.0:36.0:44.0:Scored...
# >>sending rcvd...
# Rcvd row: ['158.0', '36.0', '44.0']
# >>received 129.0:29.0:53.0:Scored...
# >>sending rcvd...
# Rcvd row: ['129.0', '29.0', '53.0']
# >>received 122.0:28.0:30.0:Scored...
# >>sending rcvd...
# Rcvd row: ['122.0', '28.0', '30.0']
# >>received 136.0:33.0:69.0:Scored...
# >>sending rcvd...
# Rcvd row: ['136.0', '33.0', '69.0']
# >>received 411.0:35.0:13.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['411.0', '35.0', '13.0']
# >>received 180.0:49.6:10.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['180.0', '49.6', '10.8']
# >>received 190.0:32.0:36.0:Scored...
# >>sending rcvd...
# Rcvd row: ['190.0', '32.0', '36.0']
# >>received 181.0:50.6:11.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['181.0', '50.6', '11.8']
# >>received 67.0:21.0:15.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['67.0', '21.0', '15.0']
# >>received 122.0:33.6:19.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['122.0', '33.6', '19.2']
# >>received 202.0:40.0:69.0:Scored...
# >>sending rcvd...
# Rcvd row: ['202.0', '40.0', '69.0']
# >>received 199.0:37.0:66.0:Scored...
# >>sending rcvd...
# Rcvd row: ['199.0', '37.0', '66.0']
# >>received 118.0:29.6:15.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['118.0', '29.6', '15.2']
# >>received 64.0:18.0:12.0:Not-scored...
# >>sending rcvd...
# Rcvd row: ['64.0', '18.0', '12.0']
# >>received 76.0:27.0:13.5:Not-scored...
# >>sending rcvd...
# Rcvd row: ['76.0', '27.0', '13.5']
# >>received 182.0:51.6:12.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['182.0', '51.6', '12.8']
# >>received 116.0:22.0:24.0:Scored...
# >>sending rcvd...
# Rcvd row: ['116.0', '22.0', '24.0']
# >>received 198.0:36.0:65.0:Scored...
# >>sending rcvd...
# Rcvd row: ['198.0', '36.0', '65.0']
# >>received 197.0:35.0:64.0:Scored...
# >>sending rcvd...
# Rcvd row: ['197.0', '35.0', '64.0']
# >>received 193.0:35.0:39.0:Scored...
# >>sending rcvd...
# Rcvd row: ['193.0', '35.0', '39.0']
# >>received 141.0:38.0:74.0:Scored...
# >>sending rcvd...
# Rcvd row: ['141.0', '38.0', '74.0']
# >>received 163.0:44.0:52.0:Scored...
# >>sending rcvd...
# Rcvd row: ['163.0', '44.0', '52.0']
# >>received 89.5:42.0:17.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['89.5', '42.0', '17.8']
# >>received 125.0:36.6:22.2:Not-scored...
# >>sending rcvd...
# Rcvd row: ['125.0', '36.6', '22.2']
# >>received 297.0:22.35:61.0:Scored...
# >>sending rcvd...
# Rcvd row: ['297.0', '22.35', '61.0']
# >>received 197.0:20.0:19.0:Scored...
# >>sending rcvd...
# Rcvd row: ['197.0', '20.0', '19.0']
# >>received 46.1:29.5:17.6:Not-scored...
# >>sending rcvd...
# Rcvd row: ['46.1', '29.5', '17.6']
# >>received 305.0:19.82:58.0:Scored...
# >>sending rcvd...
# Rcvd row: ['305.0', '19.82', '58.0']
# >>received 161.0:42.0:50.0:Scored...
# >>sending rcvd...
# Rcvd row: ['161.0', '42.0', '50.0']
# >>received 74.0:25.0:11.5:Not-scored...
# >>sending rcvd...
# Rcvd row: ['74.0', '25.0', '11.5']
# >>received 216.0:24.26:65.0:Scored...
# >>sending rcvd...
# Rcvd row: ['216.0', '24.26', '65.0']
# >>received 186.0:55.6:16.8:Not-scored...
# >>sending rcvd...
# Rcvd row: ['186.0', '55.6', '16.8']
# df received from supernode of my region has shape:  (124, 4)

# %% [markdown]
# ### Receiving x_test from supernode of region and sending pack a prediction

# %%
if status == "o":
    print("\n" + "/"*40 + " waiting for x_test " + "/"*40)
    x_test = socket_rcv(snode_connection)[len("rcv_test:"):]
    df2 = pd.DataFrame([x_test.split(":")], columns=[list(df.columns)[:-1]])
    socket_send(snode_connection, train_and_predict(df, df2)[0])

# %%
if status == "o":
    for i in range(248):
        print("\n" + "/"*40 + " waiting for x_test " + "/"*40)
        x_test = socket_rcv(snode_connection)[len("rcv_test:"):]
        df2 = pd.DataFrame([x_test.split(":")], columns=[list(df.columns)[:-1]])
        socket_send(snode_connection, train_and_predict(df, df2)[0])
# Out:
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:186.0:28.0:32.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:187.0:29.0:33.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:188.0:30.0:34.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:189.0:31.0:35.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:190.0:32.0:36.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:191.0:33.0:37.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:192.0:34.0:38.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:193.0:35.0:39.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:194.0:36.0:40.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:195.0:37.0:41.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test:160.0:41.0:49.0...
# sf:: [0.88]
# >>sending Scored...
#
# //////////////////////////////////////// waiting for x_test ////////////////////////////////////////
# >>received rcv_test